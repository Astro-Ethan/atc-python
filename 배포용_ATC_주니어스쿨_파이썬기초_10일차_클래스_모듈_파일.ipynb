# %% [markdown]
# <a href="https://colab.research.google.com/github/Astro-Ethan/atc-python/blob/main/%EB%B0%B0%ED%8F%AC%EC%9A%A9_ATC_%EC%A3%BC%EB%8B%88%EC%96%B4%EC%8A%A4%EC%BF%A8_%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%88_10%EC%9D%BC%EC%B0%A8_%ED%81%B4%EB%9E%98%EC%8A%A4_%EB%AA%A8%EB%93%88_%ED%8C%8C%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 클래스의 이해 (1)

# %% [markdown]
# - 클래스의 개념을 알아봅시다.

# %%
# 객체 지향 언어에서 중요한 개념!

# 자동차가 가진 기능(함수)을 생각해서 3가지 적어보세요 :

# 자동차가 가진 속성(변수)을 생각해서 3가지 적어보세요 :

# %% [markdown]
# ![DALL·E 2023-11-30 16.26.43 - A vibrant red car on a plain white background. The car should be depicted in a modern, sleek design, with sharp lines and a glossy finish that reflect.png](data:image/png;base64,...)

# %%
# 자동차에서 클래스란 무엇? :

# 클래스를 사용하는 이유는? :

# 클래스에 대해 한 문장으로 정의해봅시다 :

# %% [markdown]
# - 클래스를 정의하는 코딩 방법을 알아봅시다.

# %%
# 선생님의 설명을 보며 같이 클래스를 만들어 봅시다.

# 아래에 Cat이란 이름의 클래스를 만들어보세요.

# %%
# 다시 Cat 클래스를 만들고, 안에 name과 color 속성을 정의해보세요.
# 속성을 변수라고 생각하기

# %%
# 위에서 만든 속성값을 가진 Cat 클래스 코드를 그대로 복사해서 아래에 붙여넣으세요.
# 그리고 hello 매소드를 추가하는 코드를 따라서 입력해보세요.

# 메소드는 클래스 안에 들어 있는 함수

# %% [markdown]
# - 클래스로 된 객체를 생성해봅시다.

# %%
# 클래스 객체를 생성하려면 이렇게 입력해야 합니다 :

# %%
# Cat 클래스를 a, b, coco1, coco2 를 이름으로 한 객체로 생성해보세요. (아래에 코드 입력해보기)

# %% [markdown]
# - 클래스의 생성자를 이해해봅시다.

# %%
# 클래스의 생성자란 무엇인가요? 선생님의 설명을 듣고 정리해보세요. :

# %%
# 생성자를 추가하는 코드를 따라 적어봅시다.

# %%
# 위에 적은 코드를 실행한 다음 진행하세요.

# 아래의 코드 중 1번은 잘 싱행 되는데 2번에서 오류가 나는 이유가 무엇인지 생각해봅시다.

# 1번
coco = Cat("short", "복순이")

# %%
# 2번
coco = Cat()

# %%
# 2번도 오류 없이 실행되게 하려면? 1

# %%
# 2번도 오류 없이 실행되게 하려면? 2
# if문 사용해야

# %%
# 값 지정 없이

# %%
# 값 지정 하고

# %%
# 생성자를 여러 개 만들 수 있나요? : 마지막에 입력한 생성자만 저장이 됨

# %%
# 메소드 사용하기
# '.'은 '~의'라는 의미

# %%
# 메소드 사용하기 - 값 지정한 경우

# %% [markdown]
# ✅ 실습 문제

# %%
# 1. 다음과 같은 Cal 클래스를 선언하는 코드를 작성해보시오.

'''
- 객체를 생성할 때 value 속성을 0으로 초기화한다.
- 객체를 생성할 때 “안녕하세요? 계산기입니다.”를 출력한다.
'''

# 이 아래에 코드 작성

# %%
# 2. 다음과 같이 동작하는 add 매소드를 Cal 클래스에 추가하는 코드를 작성해보시오.  (위에 적은 코드 복사붙여넣기 하고 추가하기.)

# 코드
'''
mycal = Cal()
mycal.add(10)
mycal.add(20)
print(mycal.value)
'''

# 실행 결과
'''
안녕하세요? 계산기입니다.
30
'''

# 이 아래에 코드 작성

# %%
# 실행 결과 테스트

mycal = Cal()
mycal.add(10)
mycal.add(20)
print(mycal.value)

# %%
# 3. 서로 다른 이름의 Cal 클래스 객체를 2개 만들고, 첫 번째 객체의 value 속성은 10, 두 번째 객체의 value 속성은 20이 되도록 코드를 작성하시오.

# 코드를 수정하는 것이 아니라 클래스의 매소드를 이용해서 값을 변화시켜야합니다.

# %% [markdown]
# ## 클래스의 이해 (2)

# %% [markdown]
# - 클래스의 상속 이해하기

# %%
# 클래스의 상속이란? :

# 왜 상속이라는 이름을 쓸까?

# %%
# 아래 있는 Plus 클래스를 상속받아 빼기 매소드를 추가해봅시다.

class Plus :
  def 더하기(self, num1, num2):
    value = num1 + num2
    print(value)

# %%
# 확인

# %%
# 부모의 매소드를 수정해서 쓸 수 있을까?

# %%
# 확인

# %%
# 코드를 실행한 후 클래스의 상속에 대해 자신이 이해한 바를 정리해보세요.

# %% [markdown]
# ✅ 실습 문제

# %%
# 1. 다음과 같은 Plus_Minus 클래스를 상속한 후 곱하기, 나누기 매소드를 추가하는 코드를 작성해보시오. 상속받은 클래스의 이름은 자유롭게 정합니다.


class Plus_Minus :
   def __init__(self) :
      self.result = 0

   def plus (self, x) :
      self.result += x

   def minus (self, x) :
      self.result -= x

# %%
# 풀이
class Cal(Plus_Minus):
  def multi (self, x) :
      self.result *= x

  def divi (self, x) :
      self.result /= x

# %%
# 확인

cal = Cal()
cal.plus(1)
cal.multi(10)
print(cal.result)
# Out:
# 10

# %% [markdown]
# ## 모듈과 패키지의 이해

# %% [markdown]
# - 모듈이란?

# %%
# 모듈에 포함되는 것은? :

# 모듈의 확장자는? :

# 모듈을 물건에 비유하면? :

# 모듈을 만드는 이유는? :

# 모듈에 대해서 이해한 바를 정리해보세요 :

# %% [markdown]
# - 모듈을 불러오는 방법을 알아봅시다.

# %%
# 파이썬 표준 패키지(라이브러리)에서 math 모듈을 불러와봅시다.

# import 모듈_이름

# %%
# math를 'm' 이라는 별칭으로 불러와봅시다.

# %%
# 불러온 모듈에서 log라는 이름의 함수를 호출해봅시다. (매개변수는 숫자)

# %%
# 다음 조건에 맞게 코드를 작성해보세요.

# collect 모듈을 불러옵니다.
# 모듈 안에는 count 클래스가 있습니다.
# count 클래스의 most 메소드를 사용하는데 매개변수는 '블랙핑크'를 넣어보세요.

# 아래에 코드를 작성해보세요.

# %%
# 객체 생성해서도 가능

# %%
# 모듈을 불러오는 방법들을 정리해봅시다.


# import 모듈
# import 모듈 as 별명


# from import
#

# from import *
#

# %% [markdown]
# - 모듈을 만들어봅시다.

# %%
# 모듈은 코딩한 내용을 파일로 저장하는 것이라고 할 수 있습니다.

# %%
# 뒤에 있는 파일명으로 파일을 저장하겠다

# %%writefile my_calc2.py
class My_Calc2:
    def __init__ (self, x, y):
        self.x = x
        self.y = y
        print('계산을 시작합니다')
    def my_multi(self):
        return self.x * self.y
    def my_devi(self):
        return self.x / self.y
# Out:
# Overwriting my_calc2.py

# %%
# %%와 같은 것을 매직 명령어라고 합니다.
# 매직명령어들을 볼 수 있는 코드는 다음과 같습니다.
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# - 패키지(라이브러리)를 만들어봅시다.

# %%
# 패키지란 무엇인지 정리해봅시다. :

# %%
#  아래 코드를 실행시키면 폴더가 만들어진다.
# %mkdir my_package

# %%
# 폴더 안에 모듈을 만들어보자.

# %%writefile my_package/hello.py

def greeting():
    print('hello')
# Out:
# Writing my_package/hello.py

# %%
# 위에서 만든 패키지를 불러와보자

from my_package import hello
hello.greeting()
# Out:
# hello

# %% [markdown]
# ✅ 기초 로직 키우기

# %% [markdown]
# - 클래스를 이용해보기 위해 패키지(라이브러리)를 설치해봅시다.

# %%
# !pip install progress

# %% [markdown]
# - progress 클래스를 이용해봅시다.

# %% [markdown]
# ✅ 실습 문제

# %%
# 아래는 모듈에서 가져오는 명령어입니다. 실행해줍니다.

import progressbar
from time import sleep

# %%
# 모듈에 있는 클래스들을 다 불러왔기 때문에 bar 라는 이름으로 객체를 생성해주겠습니다.

bar = progressbar.ProgressBar(maxval=20).start()

# %%
# bar 객체를 이용해 표시하는 코드입니다. 아래 내용을 실행해보세요.

for i in range(20):
  sleep(0.5)
  bar.update(i)

bar.finish()

# %%
# 위 코드에서 클래스를 이용해 만든 객체 명은 무엇이었나요?

# %%
# progress 속의 파이썬 코드를 확인하고 싶다면?

# 창의 가장 왼쪽에 있는 폴더 아이콘을 눌러서 아래 경로로 들어가보세요.
# usr -> local -> lib -> python3.10 -> dist-packages -> progressbar

# %%
# 파이썬 공식 라이브러리 서버 : pypi.org
# 컨트롤 누른 상태에서 클릭하면 창이 열림

https://pypi.org/project/progress/

https://docs.streamlit.io/library/get-started/installation

# %%
#설명서 살펴보기

# %% [markdown]
# ### 실습 과제

# %% [markdown]
# - 문제 : 다섯명의 점수를 입력 받아서 각 점수의 등수를 구하는 프로그램을 작성해보자.
#
# - 힌트 1. 리스트와 인덱싱을 사용하라.
# - 힌트 2. 등수를 계산하는 변수를 만들어 활용해라. (리스트를 만들어도 된다.)

# %%
# 힌트3. 입력받는 것은 아래의 코드를 이용하라.
score = input('점수는 띄어쓰기로 구분하여 5개 입력하세요.').split()

# 코드를 아래에 작성하고, 캡쳐해서 제출해주세요.

# %%
# 어떻게 저장되고 있는지 확인

# %%
# 값 내림차순 정렬

# %%
# 등수 설정

# %%
# 100 10 1 2 3 로 입력해보기

# %%
# 해결

# %% [markdown]
# ## 참고자료

# %% [markdown]
# - 패키지와 라이브러리 의미

# %% [markdown]
# 집을 지을 때, 시멘트나 철근이 필요하다고 해서 집을 짓는 사람이 시멘트 제작이나 철광석 제련부터 할 수는 없다. 부품이나 재료는 이미 만들어진 것을 사서 쓰는 것이 효율적이다. 프로그램도 마찬가지어서 필요한 모든 부분을 한 사람이 만드는 경우는 거의 없으며 여러가지 프로그램에 공통적으로 사용되는 부분은 해당 분야의 전문가가 미리 만들어 놓은 프로그램을 가져다 사용하는 것이 현명한 선택이다. 이처럼 다른 프로그램 제작에 사용하기 위해 미리 만들어진 프로그램의 집합을 라이브러리(library)라고 한다. 파이썬에서는 라이브러리라는 용어 대신 패키지(package)라는 말을 주로 사용한다.

# %% [markdown]
# - 패키지 설치

# %% [markdown]
# 일부 패키지는 파이썬을 설치할 때 함께 설치되는데 이러한 패키지를 표준 패키지(standard package)라고 한다. 그러나 대부분의 패키지는 파이썬을 설치한 후에 별도로 설치한다. 아나콘다 배포판을 설치하면 다양한 패키지들을 추가로 기본 설치해준다. 그러나 그 외에 추가로 패키지를 더 사용해야 할 때는 사용자가 수동으로 설치해야 한다.
#
# C, C++, 자바 같은 언어는 새로운 라이브러리를 설치할 때 그 라이브러리를 제공하는 웹사이트를 일일이 방문하여 소스코드나 바이너리를 내려받아야 한다. 반면 파이썬은 모든 패키지를 한 서버에 등록해서 간단한 명령어만으로 패키지를 쉽게 내려받아 설치할 수 있다.
#
# 기본적으로 모든 파이썬 패키지는 PyPI 서버(https://pypi.org/) 라는 공식 패키지 서버에 등록된다. 하지만 아나콘다 배포판의 경우에는 PyPI가 아닌 독자적인 패키지 서버(https://anaconda.org/)를 운영하고 있으며 운영체제별로 미리 컴파일된 패키지를 제공하는 대신 PyPI보다는 제공하는 패키지의 수가 적다.

# %% [markdown]
# - pip를 이용하여 패키지 설치하기

# %% [markdown]
# pip 패키지 관리자를 이용하여 패키지를 설치하려면 콘솔 창에서 다음과 같이 입력한다.
#
# ```
# pip install 패키지이름
# ```
#
# 예를 들어 quandl이라는 이름의 패키지를 설치하려면 ``pip install quandl`` 이라고 명령한다.

# %% [markdown]
# ```
# ~$ pip install quandl
# Collecting quandl
#   Downloading https://files.pythonhosted.org/packages/12/64/6314547cb01fa75697ddba6d6d43a9f1d023c1730ffc6abf3db7a0c89222/Quandl-3.4.8-py2.py3-none-any.whl
# Collecting more-itertools<=5.0.0 (from quandl)
#
# ...(중략)...
#
# Installing collected packages: more-itertools, inflection, ndg-httpsclient, quandl
#   Found existing installation: more-itertools 7.0.0
#     Uninstalling more-itertools-7.0.0:
#       Successfully uninstalled more-itertools-7.0.0
# Successfully installed inflection-0.3.1 more-itertools-5.0.0 ndg-httpsclient-0.5.1 quandl-3.4.8
# dockeruser@7f62df393a47:~$
# ```

# %% [markdown]
# 대부분의 패키지는 내부적으로는 다른 패키지의 기능을 사용한다. 예를 들어 만약 패키지 A가 패키지 B의 기능을 사용하고 있다면 패키지 B가 설치되어 있을 때만 패키지 A를 사용할 수 있다. 이때 패키지 A가 패키지 B에 의존(depend)한다고 말한다.
# pip로 패키지를 설치하면 그 패키지가 의존하는 다른 패키지도 자동으로 설치한다. 위에서 quandl 패키지를 설치하였더니 more-itertools, ndg-httpsclient를 같이 설치한 것을 볼 수 있다.

# %% [markdown]
# ## 파일

# %% [markdown]
# ### 파일 본시 학습

# %% [markdown]
# - 파일을 만들고 내용 기록하기
#
#   - 컴퓨터를 끄기 전에 저장해두고, 그것을 나중에 다시 꺼내서 사용할 수 있도록 하기
#
# - 두 가지 종류의 저장소
#   - 빠른 저장소 RAM : 책상 서랍 (껐다 켜면 사라짐, 많이 담을 수 없음)
#     - 클래스 이름을 지으면 여기에 저장 됨
#   - 약간 느린 저장소 HDD / SSD : 사물함 (껐다 켜도 남아 있음, 많이 담을 수 있음)
#     - 오늘 배울 내용. 파일 단위로 저장 됨
#
#
# - 파일
#   - 경로
#   - 파일명(파일 이름)
#   - 확장자(파일명에 함께 붙어 있음)

# %%
# 파일을 쓰기 위해서는 파일 (         )를 만들어야 합니다.

# 파일 쓰기 객체를 만드는 코드를 정리해보세요.

# %%
# 열기 모드 두 가지:

# 파일을 쓰는 모두 두가지 :

# 이어쓰기는 :

# 이어쓰기 코드 :

# 덮어쓰기는 :

# 덮어쓰기 코드 :

# %%
# 게임에서 캐릭터의 데이터를 저장할 때는 이어쓰기? 덮어쓰기? =>

# 메모 저장 프로그램에서 새 메모를 추가해 저장한다면 이어쓰기? 덮어쓰기? =>

# %%
# 기록하기 위한 객체를 만드는 코드를 적어보세요.

# %%
# 쓰기

# %% [markdown]
# - 아래의 내용을 test01.txt 파일에 저장시켜봅시다.
#
# >안녕하세요<br>
# 줄바꿈을 하여 저장했어요.<br>
# 중간에도<br>
# 줄바꿈이 됩니다.

# %%
# 줄바꿈은 \n을 이용해보세요.
# 아래에 코드를 작성해보세요.

# %% [markdown]
# - 파일에 저장한 내용을 읽어봅시다.

# %%
# 파일을 읽기 위해서는 파일 (         )를 만들어야 합니다.

# 파일 쓰기 객체를 만드는 코드를 정리해보세요.

# %% [markdown]
# - 읽기 메서드 정리하기

# %%
#read() :

# %%
#read(10) :

# %%
#seek(15) :

# %%
#readline() :

# %%
# readline() 두 번 써서 여러 줄 읽기

# %%
# 만약 중간에 커서를 다시 올려준다면?

# %%
# 만약 커서가 중간에 있는 상태로 시작한다면?

# %%
#readlines() :

# %%
# 한 개만 꺼내와서 읽거나 저장 됨

# %% [markdown]
# - 파일을 읽은 후 변수로 처리해봅시다.

# %%
# 실습을 위해 아래 코드를 실행해주세요.


user_info = ['홍길동', '10', '50000']

f = open('./testlist.txt','wt')
for i in range(3):
  f.write(user_info[i]+'\n')

f.close()

# %%
# 파일을 읽고, 그 내용을 리스트로 만들어보는 코드를 작성하세요.

# %%
# 위에서 만든 리스트 값에서 이상한 점을 발견해보세요.
# 발견한 사람은 조용히 손들기만 해주세요.

# %%
# strip()함수는 문자 내부의 공백을 제거하는 기능을 합니다.

# %%
# 리스트 내의 모든 데이터에서 제거

# %%
# 리스트 내의 모든 데이터에서 제거 - 리스트의 길이가 바뀌는 경우

# %% [markdown]
# ### 파일 실습 문제

# %%
# 1. 다음과 같이 user.dat 파일을 작성해보세요.

'''
- 첫번째 줄 : 아이디
- 두번째 줄 : 비밀번호
- 세번째 줄 : 레벨
- 네번째 줄 : 경험치
- 다섯번째 줄 : 소지한 돈
- 여섯번재 줄 : 무기 이름
'''

# 이 아래에 코드 작성

# %%
# 2. user.dat를 열어서 다음과 같이 고치시오 (코딩으로 하는 것 아님. 옆의 창에서 직접 실행)

'''
레벨을 100, 소지한 돈을 1억으로 수정
'''

# %%
# 3. user_info 라는 리스트에 user.dat 에서 읽은 데이터를 넣으시오.

# 이 아래에 코드 작성

# %%
# 출력 예시
